# %%
from pyecharts.charts import Bar, Line
import pyecharts.options as opts

# %%
def set_line_picture(title, series_names, axis_names, x_list, y1_list, y2_list, y3_list):
    line = Line()
    line.add_xaxis(xaxis_data=x_list)
    line.add_yaxis(series_name=series_names[0], y_axis=y1_list)
    line.add_yaxis(series_name=series_names[1], y_axis=y2_list)
    line.add_yaxis(series_name=series_names[2], y_axis=y3_list)
    line.set_global_opts(
        #设置图例形状
        legend_opts=opts.LegendOpts(legend_icon='pin'),
        #设置图表主标题，副标题和标题位置
        title_opts=opts.TitleOpts(title = title, pos_left='5%'),
        #添加坐标轴名称，位置以及大小，name_gap表示名称与x轴距离，font_size是字体大小
        xaxis_opts = opts.AxisOpts(name = axis_names[0]),
        yaxis_opts = opts.AxisOpts(name = axis_names[1]),
        tooltip_opts = opts.TooltipOpts(trigger='axis')
        )
    return line

# %%
fusion_mode = ['Early_fusion', 'Late_fusion', 'Hybrid_fusion']
input_type = ['both', 'image_only', 'text_only']

# %%
"""
同一种融合方式内做对比
"""
def picture_1(i, y1_list, y2_list, y3_list):
    title = fusion_mode[i] +  ' Accuracy'
    series_names = input_type
    axis_names = ['Epoch', 'Accuracy(%)']
    x_list = [str(j) for j in range(1, 11)]
    line = set_line_picture(title, series_names, axis_names, x_list, y1_list, y2_list, y3_list)
    return line

# %%
# Early_fusion: both image_only text_only
y1_list = [78.00, 75.50, 75.75, 72.75, 75.25, 71.25, 69.75, 73.00, 73.50, 75.25]
y2_list = [62.50, 65.25, 60.50, 67.00, 62.75, 66.00, 61.50, 60.50, 59.00, 64.00]
y3_list = [70.25, 72.25, 71.75, 69.75, 71.25, 70.00, 71.00, 70.25, 71.75, 70.50]

line = picture_1(0, y1_list, y2_list, y3_list)
# 使用 render_notebook() 方法显示图表
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3f5b39db364341b5a0cfa8951483e689" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3f5b39db364341b5a0cfa8951483e689 = echarts.init(
#                     document.getElementById('3f5b39db364341b5a0cfa8951483e689'), 'white', {renderer: 'canvas'});
#                 var option_3f5b39db364341b5a0cfa8951483e689 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
# Late_fusion: both image_only text_only
y1_list = [73.00, 75.00, 75.25, 72.00, 71.25, 70.25, 69.50, 72.00, 71.75, 71.00]
y2_list = [63.00, 63.25, 65.50, 64.50, 60.25, 63.25, 58.50, 62.50, 60.00, 65.25]
y3_list = [68.00, 71.00, 71.50, 73.50, 68.75, 70.50, 71.00, 70.25, 71.00, 69.75]

line = picture_1(1, y1_list, y2_list, y3_list)
# 使用 render_notebook() 方法显示图表
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="19b203b74e4b4f36ad3ec3b59ea8002c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_19b203b74e4b4f36ad3ec3b59ea8002c = echarts.init(
#                     document.getElementById('19b203b74e4b4f36ad3ec3b59ea8002c'), 'white', {renderer: 'canvas'});
#                 var option_19b203b74e4b4f36ad3ec3b59ea8002c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
# Hybrid_fusion: both image_only text_only
y1_list = [68.00, 72.25, 71.25, 73.75, 71.50, 69.00, 71.75, 73.00, 74.00, 71.50]
y2_list = [63.00, 63.25, 65.50, 64.50, 60.25, 63.25, 58.50, 62.50, 60.00, 65.25]
y3_list = [68.00, 71.00, 71.50, 73.50, 68.75, 70.50, 71.00, 70.25, 71.00, 69.75]

line = picture_1(2, y1_list, y2_list, y3_list)
# 使用 render_notebook() 方法显示图表
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3d52f1bcfe78453eb5eaa0f87f4a8ece" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3d52f1bcfe78453eb5eaa0f87f4a8ece = echarts.init(
#                     document.getElementById('3d52f1bcfe78453eb5eaa0f87f4a8ece'), 'white', {renderer: 'canvas'});
#                 var option_3d52f1bcfe78453eb5eaa0f87f4a8ece = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...
